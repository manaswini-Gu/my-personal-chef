# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some bananas,flour,bakig powder,baking soda,sugar,milk,vanilla essence. What can I make? and give me the rescipe")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Okay, let's make some delicious banana bread! Here's a classic recipe using the ingredients you have:
#
# **Easy Banana Bread Recipe**
#
# **Ingredients:**
#
# *   3 ripe bananas, mashed
# *   1/3 cup melted butter (or oil)
# *   1 teaspoon vanilla extract
# *   1 cup sugar
# *   1 egg
# *   1 1/2 cups all-purpose flour
# *   1 teaspoon baking soda
# *   1/2 teaspoon baking powder
# *   1/4 cup milk (optional, for a moister bread)
#
# **Instructions:**
#
# 1.  **Preheat & Prep:** Preheat your oven to 350°F (175°C). Grease and flour a 9x5 inch loaf pan.
# 2.  **Mash Bananas:** In a large bowl, mash the ripe bananas until they are smooth.
# 3.  **Wet Ingredients:** Stir in the melted butter, vanilla extract, sugar, and egg into the mashed bananas until well combined.
# 4.  **Dry Ingredients:** In a separate bowl, whisk together the flour, baking soda, and baking powder.
# 5.  **Combine:** Add the dry ingredients to the wet ingredients and mix until just combined. Be careful not to overmix. If the batter seems too thick, stir in the milk.
# 6.  **Bake:** Pour the batter into the prepared loaf pan and bake for 55-65 minutes, or until a toothpick inserted into the center comes out clean.
# 7.  **Cool:** Let the banana bread cool in the pan for about 10 minutes before transferring it to a wire rack to cool completely.
#
# Enjoy your homemade banana bread!

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='7de3b941-6f31-4b92-bf18-956b730b7efc'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with chicken and rice"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ce306-60ca-7be1-a423-48471a757039-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with chicken and rice'}, 'id': '4a78beb7-767f-45aa-bf10-33b5478974c1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 114, 'output_tokens': 19, 'total_tokens': 133, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='{"query": "recipes with chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe - Iowa Girl Eats", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. **Step 4:** Season **chicken breasts** that have been chopped into bite-sized pieces with **seasoned salt** and **pepper** then add to the soup pot and continue to simmer until the rice is al dente and the chicken is cooked through, 7-10 additional minutes. The dish will thicken as it cools, and you can taste the flavor much better when the chicken and rice is warm vs piping hot, so I like to let the pot sit uncovered for an additional 10 minutes or so before scooping into bowls and serving. Add dried parsley and chicken stock then turn heat up to high to bring to a boil, stirring occasionally to ensure the rice doesn’t stick to the bottom of the pot as it comes to a boil.", "score": 0.999959, "raw_content": null}, {"url": "https://cooking.nytimes.com/recipes/9118-easy-chicken-and-rice", "title": "Easy Chicken and Rice Recipe - NYT Cooking", "content": "# Easy Chicken and Rice. You can easily vary this dish by using any stock instead of water; by substituting another grain, like pearled barley, for the rice; by sautéing or roasting the chicken separately and combining it with the rice at the last minute; by adding sausage or shellfish, like shrimp, along with the chicken, or, most excitingly, by adding strips of red pepper, pitted olives, capers, chopped tomatoes or shelled peas to the initial onion mix. Nestle chicken in rice, add a little more salt and pepper and pour in the boiling water. Browned chicken thighs are nestled in rice with green olives, lemon slices and parsley. One-Pot Chicken and Rice With Caramelized Lemon. I added 2 cloves garlic, minced, with the rice and used low-sodium chicken broth instead of water. Push chicken into rice, add more salt & pepper. ### More From Easy Chicken Recipes for Busy Weeknights. Red Curry Chicken and Rice Bowls. ### Red Curry Chicken and Rice Bowls.", "score": 0.9999076, "raw_content": null}, {"url": "https://www.budgetbytes.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Budget Bytes", "content": "This Chicken and Rice one pot meal is the kind of comfort food I make time and time again, and it’s definitely moving to the top of my list of favorite recipes. This super simple dish includes juicy chicken thighs coated in herbs and spices (not spicy!), sautéed onions, and long grain white rice cooked in vegetable broth. You could also mix in some thawed and chopped frozen broccoli (like I do in my cheesy chicken and rice casserole recipe) when you add the broth! Since I didn’t add any vegetables *in* the pot with my chicken and rice, I added some roasted broccoli on the side. *This Chicken and Rice recipe was originally published 5/21/22. So easy to try many different types of spice profiles- this would be a great base, for instance- for Spanish rice and chicken one pot meal- just get some tomato bouillon and some tomato paste added after the onions would make a really excellent alternative- season the chicken with adobo, beans as a side etc.", "score": 0.9998969, "raw_content": null}, {"url": "https://www.recipetineats.com/oven-baked-chicken-and-rice/", "title": "Oven Baked Chicken and Rice - RecipeTin Eats", "content": "This oven baked Chicken and Rice recipe has captured the hearts of people all around the world! ## **Chicken and rice recipe**. * it’s a **one pan dinner** – the raw rice and chicken are cooked together at the same time;. So here’s what you get in this chicken and rice recipe – juicy seasoned chicken…. * **Skin on, bone in chicken thighs** is best for this recipe because they ta ...
#               AIMessage(content='You have some leftover chicken and rice! Here are a few ideas for what you can make:\n\n*   **One-Pot Chicken and Rice:** This is a comforting and simple dish where chicken and rice are cooked together in a single pot. You can easily add other vegetables or spices to customize it.\n*   **Easy Chicken and Rice:** This recipe is versatile and can be adapted with different stocks, grains, or even by adding other proteins like shrimp. Some variations include adding ingredients like olives, capers, or tomatoes.\n*   **Chicken and Rice Bowls:** You could make flavorful bowls with chicken and rice, potentially with a curry or other spice profile.\n\nWould you like me to find a specific recipe for any of these, or perhaps look for something else?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ce306-6d59-74e0-8caa-a248aabba0b8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1546, 'output_tokens': 157, 'total_tokens': 1703, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content='I have some bananas,flour,bakig powder,baking soda,sugar,milk,vanilla essence. What can I make?', additional_kwargs={}, response_metadata={}, id='c02efde8-5156-4def-bf2b-d7e44842f8ce'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with bananas, flour, baking powder, baking soda, sugar, milk, vanilla essence"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ce307-269b-7ab2-80f8-fbf8738b0179-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with bananas, flour, baking powder, baking soda, sugar, milk, vanilla essence'}, 'id': '1a2aebb2-a8c1-416f-b75c-53e355faa284', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1734, 'output_tokens': 32, 'total_tokens': 1766, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='{"query": "recipes with bananas, flour, baking powder, baking soda, sugar, milk, vanilla essence", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/860486404358831/posts/1560282794379185/", "title": "Recipe for ripe bananas with flour and baking powder - Facebook", "content": "Banana Bread 2 cups of cake flour 2 tsps of baking powder 125g of margarine or butter 1 tsp of vanilla essence 2 beaten eggs 4 mashed bananas", "score": 0.9999827, "raw_content": null}, {"url": "https://www.facebook.com/makeupbyjesslyn/videos/banana-bread-reciperecipe%EF%B8%8Fin-a-bowl-smash2-ripe-bananasin-a-seperate-bowl-whisk-/666220036056193/", "title": "BANANA BREAD RECIPE     Recipe⤵️ ••In a bowl smash: 2 ripe ...", "content": "In another seperate bowl add: 1 1/2cup: Flour 1 tsp: Baking Soda 1 tsp: Baking Powder 1 tsp: Vanilla Extract 1/2 tsp: Salt 1/2 tsp: Cinammon ••", "score": 0.99963737, "raw_content": null}, {"url": "https://scientificallysweet.com/classic-banana-bread-recipe/", "title": "THE BEST Classic Banana Bread Recipe - Scientifically Sweet", "content": "Preheat oven to 400°F. · Whisk together flour, baking powder, baking soda, salt and spices in medium bowl. · Place mashed banana in a large mixing", "score": 0.9986223, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=9P2XmtqyK2M", "title": "If You Have Banana & Flour At Home Make This Dessert ... - YouTube", "content": "... Recipe: Ingredients: 2cups/250g-All Purpose Flour or Cake/Soft Flour ... Milk 1cup - Banana Recipes You May Love Ghana Pound Cake Recipe", "score": 0.9985335, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=xchG2ouOs6s", "title": "HOW TO MAKE MOIST AND FLUFFY BANANA CAKE - YouTube", "content": "INGREDIENTS 4 medium sized bananas 1 1/2 cup of flour 1/2 cup sugar 1/2 cup melted butter 1/4 milk 1/2 tsp baking powder 1/2 tsp baking soda 1", "score": 0.9978173, "raw_content": null}], "response_time": 0.73, "request_id": "0fc463f7-036b-4c12-a2f3-b46c3901975f"}', name='web_search', id='964374d4-a17b-4983-bbd3-0b18e3d1c1de', tool_call_id='1a2aebb2-a8c1-416f-b75c-53e355faa284'),
#               AIMessage(content='With those ingredients, you can make delicious **banana bread** or **banana cake**!\n\nWould you like a recipe for either of those?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ce307-2ffc-7d62-a409-8cb3ff05372a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2515, 'output_tokens': 29, 'total_tokens': 2544, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content='I have some bananas,flour,bakig powder,baking soda,sugar,milk,vanilla essence. What can I make? and give me the rescipe', additional_kwargs={}, response_metadata={}, id='50158dcb-0248-4fb9-96e9-6aaf29bbf7cb'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "easy banana bread recipe with flour, baking powder, baking soda, sugar, milk, vanilla essence, and bananas"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ce307-aaf5-7a23-b110-15fb836e8331-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'easy banana bread recipe with flour, baking powder, baking soda, sugar, milk, vanilla essence, and bananas'}, 'id': '9d5c7967-aacc-40ac-8f9d-d2e35cdf053a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2581, 'output_tokens': 36, 'total_tokens': 2617, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='{"query": "easy banana bread recipe with flour, baking powder, baking soda, sugar, milk, vanilla essence, and bananas", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.allrecipes.com/recipe/6757/simple-banana-bread/", "title": "Simple Banana Bread Recipe - Allrecipes", "content": "I developed this banana bread recipe without baking soda because I had limited ingredients and wanted a bread recipe, not cake-like, while living in a 10-foot trailer. I actually decided on this recipe since it called for baking powder instead of soda (which I didn\'t have) I halved the recipe since I cook for one and I definitely don\'t need a whole loaf lying around =) I did add about 2 T of melted butter to the batter as another reviewer suggested to make it a little more moist and just a dash more baking powder. If you use bananas that are not ripe enough it won\'t be a substitute for the liquid (i.e. milk, water) that most recipes have and the bread won\'t turn out right). This is a great recipe if you like true banana BREAD. This is my favorite Banana Bread Recipe. This is a great recipe if you like true banana BREAD.", "score": 0.9999318, "raw_content": null}, {"url": "https://sosrecipes.com/the-best-banana-bread-recipe/", "title": "The Best Banana Bread Recipe", "content": "# THE BEST BANANA BREAD RECIPE. My family loves homemade banana bread recipe so much, it’s a staple at our home. You can add other ingredients like nuts or chocolate chips, but we like the classic banana bread recipe the best. ## **INGREDIENTS IN CLASSIC BANANA BREAD RECIPE**. *For this classic banana bread recipe, all you need is:*. Very ripe bananas, butter (doesn’t matter if you only have salted butter, it’s ok), egg, flour, sugar, vanilla extract and baking soda and a pinch of salt. ## **IS BANANA BREAD MADE USING BAKING SODA OR BAKING POWDER?**. It not only makes the bread rise, but also helps give it a very appealing brown color and helps make a moist banana bread recipe. In the case of this recipe, since it calls for 1 ½ cups of flour, you would need to use 1 ½ teaspoons of baking powder. ## THE BEST BANANA BREAD RECIPE. After you make the Banana bread does it need to be put in the fridge.", "score": 0.99954873, "raw_content": null}, {"url": "https://scientificallysweet.com/classic-banana-bread-recipe/", "title": "THE BEST Classic Banana Bread Recipe - Scientifically Sweet", "content": "Ingredients · 1 ⅔ cups (235g) all-purpose flour · 1 ½ teaspoon baking powder · ½ teaspoon baking soda · ½ teaspoon salt · 1 teaspoon ground cinnamon", "score": 0.998487, "raw_content": null}, {"url": "https://www.thekitchn.com/how-to-make-banana-bread-the-simplest-easiest-recipe-139900", "title": "Classic Banana Bread (Best Recipe Ever) - The Kitchn", "content": "Ingredients · Cooking spray · 8 tablespoons. (1 stick) unsalted butter · 1 cup. granulated sugar · 2. large eggs · 1/4 cup. milk · 1 teaspoon. vanilla", "score": 0.99843913, "raw_content": null}, {"url": "https://www.facebook.com/groups/860486404358831/posts/1791153007958828/", "title": "Recipe for homemade banana bread with detailed ingredients and ...", "content": "Add sugar, oil (or butter), eggs, and vanilla. Mix well. 4. In another bowl, combine flour, baking soda, baking powder, salt, and spice. 5", "score": 0.998147, "raw_content": null}], "response_time": 2.95, "request_id": "6f3b619d-5df4-4dcf-b454-36882b085286"}', name='web_search', id='dab5e7e3-fc40-42f1-aa4e-80177db75aca', tool_call_id='9d5c7967-aacc-40ac-8f9d-d2e35cdf053a'),
#               AIMessage(content="Okay, let's make some delicious banana bread! Here's a classic recipe using the ingredients you have:\n\n**Easy Banana Bread Recipe**\n\n**Ingredients:**\n\n*   3 ripe bananas, mashed\n*   1/3 cup melted butter (or oil)\n*   1 teaspoon vanilla extract\n*   1 cup sugar\n*   1 egg\n*   1 1/2 cups all-purpose flour\n*   1 teaspoon baking soda\n*   1/2 teaspoon baking powder\n*   1/4 cup milk (optional, for a moister bread)\n\n**Instructions:**\n\n1.  **Preheat & Prep:** Preheat your oven to 350°F (175°C). Grease and flour a 9x5 inch loaf pan.\n2.  **Mash Bananas:** In a large bowl, mash the ripe bananas until they are smooth.\n3.  **Wet Ingredients:** Stir in the melted butter, vanilla extract, sugar, and egg into the mashed bananas until well combined.\n4.  **Dry Ingredients:** In a separate bowl, whisk together the flour, baking soda, and baking powder.\n5.  **Combine:** Add the dry ingredients to the wet ingredients and mix until just combined. Be careful not to overmix. If the batter seems too thick, stir in the milk.\n6.  **Bake:** Pour the batter into the prepared loaf pan and bake for 55-65 minutes, or until a toothpick inserted into the center comes out clean.\n7.  **Cool:** Let the banana bread cool in the pan for about 10 minutes before transferring it to a wire rack to cool completely.\n\nEnjoy your homemade banana bread!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ce307-bc79-76f1-a362-9b30c19241a3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3618, 'output_tokens': 357, 'total_tokens': 3975, 'input_token_details': {'cache_read': 0}})]}
